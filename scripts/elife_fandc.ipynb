# %%
# !ls
# Out:
# eLife.00003.html  eLife.00534.html  eLife.00961.html  eLife.01460.html	eLife.01993.html
# eLife.00005.html  eLife.00537.html  eLife.00963.html  eLife.01462.html	eLife.01998.html
# eLife.00007.html  eLife.00542.html  eLife.00966.html  eLife.01465.html	eLife.02001.html
# eLife.00011.html  eLife.00558.html  eLife.00967.html  eLife.01469.html	eLife.02008.html
# eLife.00012.html  eLife.00563.html  eLife.00969.html  eLife.01473.html	eLife.02024.html
# eLife.00013.html  eLife.00565.html  eLife.00971.html  eLife.01479.html	eLife.02025.html
# eLife.00031.html  eLife.00569.html  eLife.00983.html  eLife.01481.html	eLife.02028.html
# eLife.00036.html  eLife.00571.html  eLife.00992.html  eLife.01482.html	eLife.02030.html
# eLife.00047.html  eLife.00572.html  eLife.00994.html  eLife.01483.html	eLife.02040.html
# eLife.00048.html  eLife.00573.html  eLife.00996.html  eLife.01488.html	eLife.02041.html
# eLife.00049.html  eLife.00577.html  eLife.00999.html  eLife.01489.html	eLife.02042.html
# ...

# %%
from bs4 import BeautifulSoup

# %%
import os, shutil

# %%
soup = BeautifulSoup (open("eLife.00003.html"))

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" version="HTML+RDFa+MathML 1.1" xmlns="http://www.w3.org/1999/xhtml" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:mml="http://www.w3.org/1998/Math/MathML" xmlns:og="http://ogp.me/ns#" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
#  <head prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book#">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="/node/3" rel="shortlink"/>
#   <link href="http://dex3165296d6d.cloudfront.net/sites/default/themes/elife/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=10, minimum-scale=1, user-scalable=yes" name="viewport"/>
# ...

# %% [raw]
# <div class="fig-inline-img">
#                                    <a class="colorbox colorbox-load figure-expand-popup" data-figure-caption="&amp;lt;div class=&amp;quot;fig-caption&amp;quot; xmlns:xhtml=&amp;quot;http://www.w3.org/1999/xhtml&amp;quot;&amp;gt;&amp;lt;span class=&amp;quot;fig-label&amp;quot;&amp;gt;Figure 5.&amp;lt;/span&amp;gt; &amp;lt;span class=&amp;quot;caption-title&amp;quot;&amp;gt;Bacterial cell wall components release droplet bounds histones in a dose dependent manner.&amp;lt;/span&amp;gt;&amp;lt;p id=&amp;quot;p-42&amp;quot;&amp;gt;(&amp;lt;strong&amp;gt;A&amp;lt;/strong&amp;gt;). Increasing concentrations of lipopolysaccharide (LPS) in the buffer releases droplet bound histones from purified LDs. (&amp;lt;strong&amp;gt;B&amp;lt;/strong&amp;gt;). Lipoteichoic acid (LTA) causes the dose dependent release of histones from purified droplets. LDs were purified from wild-type &amp;lt;em&amp;gt;Drosophila&amp;lt;/em&amp;gt; embryos, re-suspended in buffer, and incubated for 2 hr at room temperature with different concentrations of LPS or LTA. LDs (LD) were then separated from the under-layer buffer (UB) and both were processed for SDS-PAGE. Western Blot analysis was carried out with H2B histone antibodies.&amp;lt;/p&amp;gt;&amp;lt;p id=&amp;quot;p-43&amp;quot;&amp;gt;&amp;lt;strong&amp;gt;DOI:&amp;lt;/strong&amp;gt; &amp;lt;a href=&amp;quot;/lookup/doi/10.7554/eLife.00003.010&amp;quot;&amp;gt;http://dx.doi.org/10.7554/eLife.00003.010&amp;lt;/a&amp;gt;&amp;lt;/p&amp;gt;&amp;lt;div class=&amp;quot;sb-div caption-clear&amp;quot;&amp;gt;&amp;lt;/div&amp;gt;&amp;lt;/div&amp;gt;" data-powerpoint-url="/highwire/powerpoint/79" href="/content/elife/1/e00003/F8.large.jpg" rel="gallery-fragment-images-79" title="Figure 5.">
#                                     <img alt="Figure 5." data-img="/content/elife/1/e00003/F8.medium.gif" src="http://dex3165296d6d.cloudfront.net//content/elife/1/e00003/F8.medium.gif"/>
#                                    </a>
#                                   </div>
#                                   <div class="fig-caption">
#                                    <span class="elife-figure-links">
#                                     <span class="elife-figure-link elife-figure-link-download">
#                                      <a href="/content/elife/1/e00003/F8.large.jpg?download=true">
#                                       Download figure
#                                      </a>
#                                     </span>
#                                     <span class="elife-figure-link elife-figure-link-newtab">
#                                      <a href="/content/elife/1/e00003/F8.large.jpg" target="_new">
#                                       Open in new tab
#                                      </a>
#                                     </span>
#                                     <span class="elife-figure-link elife-figure-link-ppt">
#                                      <a href="/highwire/powerpoint/79">
#                                       Download powerpoint
#                                      </a>
#                                     </span>
#                                    </span>
#                                    <span class="fig-label">
#                                     Figure 5.
#                                    </span>
#                                    <span class="caption-title">
#                                     Bacterial cell wall components release droplet bounds histones in a dose dependent manner.
#                                    </span>
#                                    <p id="p-42">
#                                     (
#                                     <strong>
#                                      A
#                                     </strong>
#                                     ). Increasing concentrations of lipopolysaccharide (LPS) in the buffer releases droplet bound histones from purified LDs. (
#                                     <strong>
#                                      B
#                                     </strong>
#                                     ). Lipoteichoic acid (LTA) causes the dose dependent release of histones from purified droplets. LDs were purified from wild-type
#                                     <em>
#                                      Drosophila
#                                     </em>
#                                     embryos, re-suspended in buffer, and incubated for 2 hr at room temperature with different concentrations of LPS or LTA. LDs (LD) were then separated from the under-layer buffer (UB) and both were processed for SDS-PAGE. Western Blot analysis was carried out with H2B histone antibodies.
#                                    </p>
#                                    <p id="p-43">
#                                     <strong>
#                                      DOI:
#                                     </strong>
#                                     <a href="/lookup/doi/10.7554/eLife.00003.010">
#                                      http://dx.doi.org/10.7554/eLife.00003.010
#                                     </a>
#                                    </p>
#                                    <div class="sb-div caption-clear">
#                                    </div>
#                                   </div>
#                                   <span class="highwire-journal-article-marker-end">
#                                   </span>
#                                  </div>
#                                  <span id="related-urls">
#                                  </span>
#                                 </div>
#                                </div>
#                               </div>
#                              </div>

# %%
strong = soup.find_all('strong')

# %%
for link in strong:
    print link
# Out:
# <strong>DOI:</strong>
# <strong>DOI:</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>A</strong>
# <strong>C</strong>
# <strong>D</strong>
# <strong>C</strong>
# <strong>E</strong>
# <strong>F</strong>
# <strong>DOI:</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>C</strong>
# <strong>D</strong>
# <strong>E</strong>
# <strong>F</strong>
# <strong>G</strong>
# <strong>DOI:</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>C</strong>
# <strong>D</strong>
# <strong>B</strong>
# <strong>DOI:</strong>
# <strong>DOI:</strong>
# <strong>DOI:</strong>
# <strong>DOI:</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>C</strong>
# <strong>D</strong>
# <strong>DOI:</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>DOI:</strong>
# <strong>A</strong>
# <strong>B</strong>
# <strong>C</strong>
# <strong>D</strong>
# <strong>C</strong>
# <strong>D</strong>
# <strong>DOI:</strong>
# ...

# %%
strong = soup.find_all('em')

# %%
for link in strong:
    print link
# Out:
# <em>Drosophila</em>
# <em>Drosophila</em>
# <em>Drosophila</em>
# <em>C. elegans</em>
# <em>Drosophila</em>
# <em>Drosophila</em>
# <em>Escherichia coli</em>
# <em>Staphylococcus epidermidis</em>
# <em>Escherichia coli DH5α</em>
# <em>Staphylococcus epidermidis</em>
# <em>E. coli</em>
# <em>Drosophila</em>
# <em>E. coli ML35</em>
# <em>Drosophila</em>
# <em>E. coli</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>zl01</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>f07560</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>zl01</em>
# <em>Jabba</em>
# <em>zl01</em>
# <em>Jabba</em>
# <em>f07560</em>
# <em>Jabba</em>
# <em>zl01</em>
# <em>Jabba</em>
# <em>f07560</em>
# <em>Jabba</em>
# <em>zlo1</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>E. coli</em>
# <em>Jabba</em>
# <em>Jabba</em>
# <em>Jabba</em>
# ...

# %%
figfig = soup.find_all('div', class_="fig-caption")
print(figfig)
# Out:
# [<div class="fig-caption"><span class="elife-figure-links"><span class="elife-figure-link elife-figure-link-download"><a href="/content/elife/1/e00003/F1.large.jpg?download=true">Download figure</a></span><span class="elife-figure-link elife-figure-link-newtab"><a href="/content/elife/1/e00003/F1.large.jpg" target="_new">Open in new tab</a></span><span class="elife-figure-link elife-figure-link-ppt"><a href="/highwire/powerpoint/72">Download powerpoint</a></span></span><span class="fig-label">Figure 1.</span> <span class="caption-title">LDs kill bacteria via droplet bound histones.</span><p id="p-15">(<strong>A</strong>). Representative plates in a colony forming assay, showing growth of Gram-negative (<em>Escherichia coli DH5α</em>, top) and Gram-positive (<em>Staphylococcus epidermidis</em>, bottom) bacteria, where a known amount of bacteria were incubated at 37°C either in buffer alone, or with LDs pre-treated with or without anti-histone antibodies. In buffer (left, ‘Buffer’), ma
# ...

# %% [raw]
#  <div class="fig-caption">
#                                    <span class="elife-figure-links">
#                                     <span class="elife-figure-link elife-figure-link-download">
#                                      <a href="/content/elife/1/e00003/F8.large.jpg?download=true">
#                                       Download figure
#                                      </a>
#                                     </span>
#                                     <span class="elife-figure-link elife-figure-link-newtab">
#                                      <a href="/content/elife/1/e00003/F8.large.jpg" target="_new">
#                                       Open in new tab
#                                      </a>
#                                     </span>

# %%
dirname = ("1.html")
chomped = dirname[:-5]
print dirname
print chomped
# Out:
# 1.html
# 1

# %%
file = open("./"+chomped+"/"+chomped+"-imgs.txt", "wb")

# %%
for link in soup.find_all(class_="elife-figure-link elife-figure-link-newtab"):
        img = link.a.get('href').encode("utf8")
        print(link.a.get('href')).encode("utf8") #print in terminal to verify results
        #winner = link.fullink('href')
        #print(winner)
        #dirname = os.path.splitext("string.html")[0]
        file.write("http://elifesciences.org"+img+'\n')
# Out:
# /content/elife/1/e00003/F1.large.jpg
# /content/elife/1/e00003/F2.large.jpg
# /content/elife/1/e00003/F3.large.jpg
# /content/elife/1/e00003/F3/F4.large.jpg
# /content/elife/1/e00003/F3/F5.large.jpg
# /content/elife/1/e00003/F3/F6.large.jpg
# /content/elife/1/e00003/F7.large.jpg
# /content/elife/1/e00003/F8.large.jpg
# /content/elife/1/e00003/F9.large.jpg

# %%
file.flush()
file.close()

# %%
file = open("./"+chomped+"/"+chomped+"-caps.txt", "wb")

# %%
for dink in soup.find_all('div', class_="fig-caption"):
    #print(dink.get_text(separator=' '))
    cap = dink.get_text(separator=' ').replace('Download figure Open in new tab Download powerpoint ','').encode("utf8")
    file.write(str(cap)+'\n')

# %%
file.flush()
file.close()

# %%
for a in soup.find_all('meta', name_="citation_author"):
        print (a.get_text())
